# %% [markdown]
# Student Performance
# The dataset is related to student performance and attributes in secondary education. Here's a general introduction based on the columns present in the DataFrame:
#
# This dataset contains information about students in secondary education, including demographic details, family background, educational support, lifestyle choices, and academic performance. Each row represents a unique student, and the columns provide various attributes and characteristics associated with them.
#
# Dataset contains following colum

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('student-por.csv')
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (649, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
#Univariate analysis of school

# %%
df['school'].unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
df["school"].value_counts()
# Out:
# school
# GP    423
# MS    226
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="school",data=df,palette = 'pastel')
plt.title('Dist of schools')
plt.show()

# %%
#gp has large no of students

# %%
#univariate analysis of age
sns.histplot(x="age",kde=True,data=df,palette = 'pastel')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
#most common age group >> 16--17

# %%
df['address'].unique()
# Out:
# array(['U', 'R'], dtype=object)

# %%
#univariate analysis of address
df['address'].value_counts()
# Out:
# address
# U    452
# R    197
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="address",data=df,palette=['red','green'])
plt.show()

# %%
#there are many students from urbnan areas

# %%
df['reason'].unique()
# Out:
# array(['course', 'other', 'home', 'reputation'], dtype=object)

# %%
c=df['reason'].value_counts()
c
# Out:
# reason
# course        285
# home          149
# reputation    143
# other          72
# Name: count, dtype: int64

# %%
plt.pie(c,labels = c.index,autopct = '%1.1f%%')
plt.show()

# %%
##common reason>> would be course

# %%
act = df['activities'].value_counts()
act
# Out:
# activities
# no     334
# yes    315
# Name: count, dtype: int64

# %%
plt.pie(act,labels=act.index,colors=['yellow','blue'],autopct ='%1.1f%%')
plt.show()

# %%
#48.5% are participating

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
# Walc: Weekend alcohol consumption (from 1 - very low to 5 - very high)
weekend_alcoholo_consumption=df['Walc'].value_counts()
weekend_alcoholo_consumption
# Out:
# Walc
# 1    247
# 2    150
# 3    120
# 4     87
# 5     45
# Name: count, dtype: int64

# %%
label=[str(i)+" " + "week" for i in weekend_alcoholo_consumption.index ]

# %%
plt.pie(weekend_alcoholo_consumption,labels=label,colors=["red","green","blue","yellow","pink"],autopct = '%1.1f%%')
plt.title('weekend alchol consumption')
plt.show()

# %% [markdown]
# studednt drinlked alcholo in mostly 1st week

# %%
df['Walc'].unique()
# Out:
# array([1, 3, 2, 4, 5])

# %%
#Bivariate analysis

df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.countplot(x='Medu',data=df,palette="Set2")
plt.title("mother education level distr")

plt.subplot(1,2,2)
sns.countplot(x='Fedu',data=df,palette="Set3")
plt.title("father education level distr")
plt.show()

# %% [markdown]
# You used plt.subplot(1, 2, 1) and
# plt.subplot(1, 2, 2) because we wanted to
# show two plots side‑by‑side in the same figure.

# %% [markdown]
# plt.subplot(rows, cols, index)

# %%
print(df.columns)
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
sns.barplot(x = 'studytime', y = 'G3', data=df,palette="Set2")
plt.show()

# %%
sns.barplot(x = 'studytime', y = 'G2', data=df,palette="Set3")
plt.show()

# %%
#multivariate
sns.barplot(x = 'sex', y = 'G3', hue = 'address', data=df, palette = 'Set2')
plt.show()

# %%
num_columns=df.select_dtypes(include="number").columns
num_columns
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3'],
#       dtype='object')

# %%
num_columns.shape
# Out:
# (16,)

# %%
sns.boxplot(data = df[num_columns], palette = 'Set2')
# Out:
# <Axes: >

# %%
corr=df.corr(numeric_only=True)
plt.figure(figsize = (12, 10))
sns.heatmap(corr, annot = True, cmap = "coolwarm", fmt = ".2f")
plt.show()

# %%
corr=df.corr(numeric_only=True).columns.shape
corr
# Out:
# (16,)
